# %%
print("Hello Python World,I am here, loock at me ")
# Out:
# Hello Python World,I am here, loock at me

# %%
print('second Helloo')
# Out:
# second Helloo

# %% [markdown]
# built in function in python
#
# in python some functions are predefined like print or mathematic operations or data containers types.but most functions are not pre defined and they are in the libraries which we have to import in our codes.

# %%
a = "Hamid"

# %%
T = 'is not bad'

# %%
print(a,T) # in this code a and T are variables, so we should not add "" or ''
# Out:
# Hamid is not bad

# %%
a,T  #For getting results print is not mandatory!
# Out:
# ('Hamid', 'is not bad')

# %% [markdown]
# there is no difference between '--' abd "" and machines understands both of them as string maker.in pyhton in selection of variable name we have to care about capital alphabet

# %% [markdown]
# HOW TO DEFINE A DICTIONARY IN PYTHON
#
# in python we have 2 data containers which are dictionary, list and array
#
# we define dictionary with curly bracket {} dictionary has 2 elements :key which is shown by ' if it is string ' or only number and then value ** which is written after:
#
# dict={1:"favtutor",2:"python"}
#
# 1 and 2 are key the others are value

# %%
prices = {'Eggs':4.5,'Steak':25.5,'Beer':3.5,'Bacon':5.3,100:'Discount','Milk':{3.5,10}}

# %% [markdown]
# double click (or enter) to edit
#
# type is a function to show us the type of the variable in python

# %%
type(prices)
# Out:
# dict

# %%
prices
# Out:
# {'Eggs': 4.5,
#  'Steak': 25.5,
#  'Beer': 3.5,
#  'Bacon': 5.3,
#  100: 'Discount',
#  'Milk': {3.5, 10}}

# %%
type(a)
# Out:
# str

# %%
prices['Eggs']
# Out:
# 4.5

# %%
prices["Steak"] # " or ''are same for strings
# Out:
# 25.5

# %%
prices[100]
# Out:
# 'Discount'

# %%
prices['Discount']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2582964991.py in <cell line: 0>()
# ----> 1 prices['Discount']
#
# KeyError: 'Discount'

# %% [markdown]
# to call a specific amount we should write : dictionary name [the name of the key],if the key is string we should put it inside of two ''but if the keys are number, we should not use ''.We can call the value by key, but can not call the key by value in dictionary format

# %%
list1 = [10,'Your name',"Class",10,[1,2,[3,4]]] # the order numbering in python starts from 0, therefore the first element

list1
# Out:
# [10, 'Your name', 'Class', 10, [1, 2, [3, 4]]]

# %%
list1[1]
# Out:
# 'Your name'

# %%
list1[0]
# Out:
# 10

# %%
list1[4][2][0]
# Out:
# 3

# %%
list1[0] =100 # change the value in the list
list1
# Out:
# [100, 'Your name', 'Class', 10, [1, 2, [3, 4]]]
